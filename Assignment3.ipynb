# %%
import numpy as np
import pandas as pd

# %%
disease=pd.read_csv('heart_disease.csv')

# %%
disease
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
disease.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# ...

# %%
disease.tail()
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# 319790           0.0         Yes    Male        60-64  Hispanic      Yes
# 319791           0.0          No    Male        35-39  Hispanic       No
# 319792           0.0          No  Female        45-49  Hispanic       No
# 319793           0.0          No  Female        25-29  Hispanic       No
# 319794           0.0          No  Female  80 or older  Hispanic       No
#
#        PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# ...

# %%
disease.dtypes
# Out:
# HeartDisease         object
# BMI                 float64
# Smoking              object
# AlcoholDrinking      object
# Stroke               object
# PhysicalHealth      float64
# MentalHealth        float64
# DiffWalking          object
# Sex                  object
# AgeCategory          object
# Race                 object
# Diabetic             object
# PhysicalActivity     object
# GenHealth            object
# SleepTime           float64
# Asthma               object
# KidneyDisease        object
# SkinCancer           object
# dtype: object

# %%
disease.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
#        'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')

# %%
disease.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319789 non-null  float64
#  2   Smoking           319721 non-null  object
#  3   AlcoholDrinking   319680 non-null  object
#  4   Stroke            319774 non-null  object
#  5   PhysicalHealth    319778 non-null  float64
#  6   MentalHealth      319781 non-null  float64
#  7   DiffWalking       319762 non-null  object
#  8   Sex               319482 non-null  object
#  9   AgeCategory       319751 non-null  object
#  10  Race              319756 non-null  object
#  11  Diabetic          319762 non-null  object
#  12  PhysicalActivity  319779 non-null  object
#  13  GenHealth         319302 non-null  object
#  14  SleepTime         319576 non-null  float64
# ...

# %%
disease.isnull()
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0              False  False    False            False   False           False
# 1              False  False    False            False   False           False
# 2              False  False    False            False   False           False
# 3              False  False    False            False   False           False
# 4              False  False    False            False   False           False
# ...              ...    ...      ...              ...     ...             ...
# 319790         False  False    False            False   False           False
# 319791         False  False    False            False   False           False
# 319792         False  False    False            False   False           False
# 319793         False  False    False            False   False           False
# 319794         False  False    False            False   False           False
#
# ...

# %%
disease.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  319789.000000   319778.000000  319781.000000  319576.000000
# mean       28.325348        3.371605       3.898384       7.096922
# std         6.356134        7.950662       7.955291       1.436165
# min        12.020000        0.000000       0.000000       1.000000
# 25%        24.030000        0.000000       0.000000       6.000000
# 50%        27.340000        0.000000       0.000000       7.000000
# 75%        31.420000        2.000000       3.000000       8.000000
# max        94.850000       30.000000      30.000000      24.000000

# %%
disease.isnull().sum()
# Out:
# HeartDisease          0
# BMI                   6
# Smoking              74
# AlcoholDrinking     115
# Stroke               21
# PhysicalHealth       17
# MentalHealth         14
# DiffWalking          33
# Sex                 313
# AgeCategory          44
# Race                 39
# Diabetic             33
# PhysicalActivity     16
# GenHealth           493
# SleepTime           219
# Asthma                0
# KidneyDisease        17
# SkinCancer            0
# dtype: int64

# %%
disease.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 319790    False
# 319791    False
# 319792    False
# 319793    False
# 319794    False
# Length: 319795, dtype: bool

# %%
disease.duplicated().sum()
# Out:
# 17965

# %%
disease.BMI.describe()
# Out:
# count    319789.000000
# mean         28.325348
# std           6.356134
# min          12.020000
# 25%          24.030000
# 50%          27.340000
# 75%          31.420000
# max          94.850000
# Name: BMI, dtype: float64

# %%
BMI_mean=disease.BMI.mean()
BMI_mean
# Out:
# 28.325348432872918

# %%
disease.describe(include=object)
# Out:
#        HeartDisease Smoking AlcoholDrinking  Stroke DiffWalking     Sex  \
# count        319795  319721          319680  319774      319762  319482
# unique            2       2               2       2           2       2
# top              No      No              No      No          No  Female
# freq         292422  187843          297908  307706      275363  167591
#
#        AgeCategory    Race Diabetic PhysicalActivity  GenHealth  Asthma  \
# count       319751  319756   319762           319779     319302  319795
# unique          13       6        4                2          5       2
# top          65-69   White       No              Yes  Very good      No
# freq         34143  245189   269626           247946     113657  276923
#
#        KidneyDisease SkinCancer
# count         319778     319795
# unique             2          2
# top               No         No
# freq          308001     289976

# %%
disease.fillna({'BMI':disease['BMI'].mean()},inplace=True)

# %%
disease.isnull().sum()
# Out:
# HeartDisease          0
# BMI                   0
# Smoking              74
# AlcoholDrinking     115
# Stroke               21
# PhysicalHealth       17
# MentalHealth         14
# DiffWalking          33
# Sex                 313
# AgeCategory          44
# Race                 39
# Diabetic             33
# PhysicalActivity     16
# GenHealth           493
# SleepTime           219
# Asthma                0
# KidneyDisease        17
# SkinCancer            0
# dtype: int64

# %%
disease['Smoking'].describe()
# Out:
# count     319721
# unique         2
# top           No
# freq      187843
# Name: Smoking, dtype: object

# %%
disease['Smoking'].mode()
# Out:
# 0    No
# Name: Smoking, dtype: object

# %%
disease.fillna({'Smoking':disease['Smoking'].mode()[0]},inplace=True)

# %%
disease.isnull().sum()
# Out:
# HeartDisease          0
# BMI                   0
# Smoking               0
# AlcoholDrinking     115
# Stroke               21
# PhysicalHealth       17
# MentalHealth         14
# DiffWalking          33
# Sex                 313
# AgeCategory          44
# Race                 39
# Diabetic             33
# PhysicalActivity     16
# GenHealth           493
# SleepTime           219
# Asthma                0
# KidneyDisease        17
# SkinCancer            0
# dtype: int64

# %%
disease['KidneyDisease'].describe()
# Out:
# count     319778
# unique         2
# top           No
# freq      308001
# Name: KidneyDisease, dtype: object

# %%
disease.fillna({'KidneyDisease':disease['KKidneyDisease'].mode()[0]},inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'KKidneyDisease'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[107], line 1
# ...

# %%
disease.isnull().sum()
# Out:
# HeartDisease          0
# BMI                   0
# Smoking               0
# AlcoholDrinking     115
# Stroke               21
# PhysicalHealth       17
# MentalHealth         14
# DiffWalking          33
# Sex                 313
# AgeCategory          44
# Race                 39
# Diabetic             33
# PhysicalActivity     16
# GenHealth           493
# SleepTime           219
# Asthma                0
# KidneyDisease         0
# SkinCancer            0
# dtype: int64

# %%
disease['Stroke'].mode()
# Out:
# 0    No
# Name: Stroke, dtype: object

# %%
disease.fillna({'Stroke':disease['Stroke'].mode()[0]},inplace=True)

# %%
disease.isnull().sum()
# Out:
# HeartDisease          0
# BMI                   0
# Smoking               0
# AlcoholDrinking     115
# Stroke                0
# PhysicalHealth       17
# MentalHealth         14
# DiffWalking          33
# Sex                 313
# AgeCategory          44
# Race                 39
# Diabetic             33
# PhysicalActivity     16
# GenHealth           493
# SleepTime           219
# Asthma                0
# KidneyDisease         0
# SkinCancer            0
# dtype: int64

# %%
disease['PhysicalHealth'].describe()
# Out:
# count    319778.000000
# mean          3.371605
# std           7.950662
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           2.000000
# max          30.000000
# Name: PhysicalHealth, dtype: float64

# %%
disease['PhysicalHealth'].mean()
# Out:
# 3.3716046757437974

# %%
disease.fillna({'PhysicalHealth':disease['PhysicalHealth'].mean()},inplace=True)

# %%
disease.isnull().sum()
# Out:
# HeartDisease          0
# BMI                   0
# Smoking               0
# AlcoholDrinking     115
# Stroke                0
# PhysicalHealth        0
# MentalHealth         14
# DiffWalking          33
# Sex                 313
# AgeCategory          44
# Race                 39
# Diabetic             33
# PhysicalActivity     16
# GenHealth           493
# SleepTime           219
# Asthma                0
# KidneyDisease         0
# SkinCancer            0
# dtype: int64

# %%
disease["MentalHealth"].describe()
# Out:
# count    319781.000000
# mean          3.898384
# std           7.955291
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           3.000000
# max          30.000000
# Name: MentalHealth, dtype: float64

# %%
disease.fillna({'MentalHealth':disease['MentalHealth'].mean()},inplace=True)

# %%
disease.isnull().sum()
# Out:
# HeartDisease          0
# BMI                   0
# Smoking               0
# AlcoholDrinking     115
# Stroke                0
# PhysicalHealth        0
# MentalHealth          0
# DiffWalking          33
# Sex                 313
# AgeCategory          44
# Race                 39
# Diabetic             33
# PhysicalActivity     16
# GenHealth           493
# SleepTime           219
# Asthma                0
# KidneyDisease         0
# SkinCancer            0
# dtype: int64

# %%
disease['DiffWalking'].describe()
# Out:
# count     319762
# unique         2
# top           No
# freq      275363
# Name: DiffWalking, dtype: object

# %%
disease['DiffWalking'].mode()
# Out:
# 0    No
# Name: DiffWalking, dtype: object

# %%
disease.fillna({'DiffWalking':disease['DiffWalking'].mode()[0]},inplace=True)

# %%
disease.isnull().sum()
# Out:
# HeartDisease          0
# BMI                   0
# Smoking               0
# AlcoholDrinking     115
# Stroke                0
# PhysicalHealth        0
# MentalHealth          0
# DiffWalking           0
# Sex                 313
# AgeCategory          44
# Race                 39
# Diabetic             33
# PhysicalActivity     16
# GenHealth           493
# SleepTime           219
# Asthma                0
# KidneyDisease         0
# SkinCancer            0
# dtype: int64

# %%
disease['AgeCategory'].describe()
# Out:
# count     319751
# unique        13
# top        65-69
# freq       34143
# Name: AgeCategory, dtype: object

# %%
disease.fillna({'AgeCategory':disease['AgeCategory'].mode()[0]},inplace=True)

# %%
disease.isnull().sum()
# Out:
# HeartDisease          0
# BMI                   0
# Smoking               0
# AlcoholDrinking     115
# Stroke                0
# PhysicalHealth        0
# MentalHealth          0
# DiffWalking           0
# Sex                 313
# AgeCategory           0
# Race                 39
# Diabetic             33
# PhysicalActivity     16
# GenHealth           493
# SleepTime           219
# Asthma                0
# KidneyDisease         0
# SkinCancer            0
# dtype: int64

# %%
disease['Race'].describe()
# Out:
# count     319756
# unique         6
# top        White
# freq      245189
# Name: Race, dtype: object

# %%
disease.fillna({'Race':disease['Race'].mode()[0]},inplace=True)

# %%
disease['Diabetic'].describe()
# Out:
# count     319762
# unique         4
# top           No
# freq      269626
# Name: Diabetic, dtype: object

# %%
disease.fillna({'Diabetic':disease['Diabetic'].mode()[0]},inplace=True)

# %%
disease['PhysicalActivity'].describe()
# Out:
# count     319779
# unique         2
# top          Yes
# freq      247946
# Name: PhysicalActivity, dtype: object

# %%
disease.fillna({'PhysicalActivity':disease['PhysicalActivity'].mode()[0]},inplace=True)

# %%
disease.isnull().sum()
# Out:
# HeartDisease          0
# BMI                   0
# Smoking               0
# AlcoholDrinking     115
# Stroke                0
# PhysicalHealth        0
# MentalHealth          0
# DiffWalking           0
# Sex                 313
# AgeCategory           0
# Race                  0
# Diabetic              0
# PhysicalActivity      0
# GenHealth           493
# SleepTime           219
# Asthma                0
# KidneyDisease         0
# SkinCancer            0
# dtype: int64

# %%
disease.duplicated().sum()
# Out:
# 17966

# %%
duplicates=disease.duplicated()

# %%
disease=disease.drop_duplicates()

# %%
disease.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 301829 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      301829 non-null  object
#  1   BMI               301829 non-null  float64
#  2   Smoking           301829 non-null  object
#  3   AlcoholDrinking   301714 non-null  object
#  4   Stroke            301829 non-null  object
#  5   PhysicalHealth    301829 non-null  float64
#  6   MentalHealth      301829 non-null  float64
#  7   DiffWalking       301829 non-null  object
#  8   Sex               301516 non-null  object
#  9   AgeCategory       301829 non-null  object
#  10  Race              301829 non-null  object
#  11  Diabetic          301829 non-null  object
#  12  PhysicalActivity  301829 non-null  object
#  13  GenHealth         301337 non-null  object
#  14  SleepTime         301610 non-null  float64
#  15  Asthma            301829 non-null  object
# ...

# %%
disease.isna().sum()
# Out:
# HeartDisease          0
# BMI                   0
# Smoking               0
# AlcoholDrinking     115
# Stroke                0
# PhysicalHealth        0
# MentalHealth          0
# DiffWalking           0
# Sex                 313
# AgeCategory           0
# Race                  0
# Diabetic              0
# PhysicalActivity      0
# GenHealth           492
# SleepTime           219
# Asthma                0
# KidneyDisease         0
# SkinCancer            0
# dtype: int64

# %%
disease.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 301829 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      301829 non-null  object
#  1   BMI               301829 non-null  float64
#  2   Smoking           301829 non-null  object
#  3   AlcoholDrinking   301714 non-null  object
#  4   Stroke            301829 non-null  object
#  5   PhysicalHealth    301829 non-null  float64
#  6   MentalHealth      301829 non-null  float64
#  7   DiffWalking       301829 non-null  object
#  8   Sex               301516 non-null  object
#  9   AgeCategory       301829 non-null  object
#  10  Race              301829 non-null  object
#  11  Diabetic          301829 non-null  object
#  12  PhysicalActivity  301829 non-null  object
#  13  GenHealth         301337 non-null  object
#  14  SleepTime         301610 non-null  float64
#  15  Asthma            301829 non-null  object
# ...

# %%
disease['Sex'].describe()
# Out:
# count     301516
# unique         2
# top       Female
# freq      159527
# Name: Sex, dtype: object

# %%
pd.options.mode.chained_assignment = None

# %%
disease.fillna({'Sex':disease['Sex'].mode()[0]},inplace=True)

# %%
disease.isna().sum()
# Out:
# HeartDisease          0
# BMI                   0
# Smoking               0
# AlcoholDrinking     115
# Stroke                0
# PhysicalHealth        0
# MentalHealth          0
# DiffWalking           0
# Sex                   0
# AgeCategory           0
# Race                  0
# Diabetic              0
# PhysicalActivity      0
# GenHealth           492
# SleepTime           219
# Asthma                0
# KidneyDisease         0
# SkinCancer            0
# dtype: int64

# %%
disease.fillna({'GenHealth':disease['GenHealth'].mode()[0]},inplace=True)

# %%
disease.fillna({'SleepTime':disease['SleepTime'].mode()[0]},inplace=True)

# %%
disease.isna().sum()
# Out:
# HeartDisease          0
# BMI                   0
# Smoking               0
# AlcoholDrinking     115
# Stroke                0
# PhysicalHealth        0
# MentalHealth          0
# DiffWalking           0
# Sex                   0
# AgeCategory           0
# Race                  0
# Diabetic              0
# PhysicalActivity      0
# GenHealth             0
# SleepTime             0
# Asthma                0
# KidneyDisease         0
# SkinCancer            0
# dtype: int64

# %%
disease.duplicated().sum()
# Out:
# 108

# %%
duplicates=disease.duplicated()

# %%
disease=disease.drop_duplicates()

# %%
disease.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 301721 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      301721 non-null  object
#  1   BMI               301721 non-null  float64
#  2   Smoking           301721 non-null  object
#  3   AlcoholDrinking   301606 non-null  object
#  4   Stroke            301721 non-null  object
#  5   PhysicalHealth    301721 non-null  float64
#  6   MentalHealth      301721 non-null  float64
#  7   DiffWalking       301721 non-null  object
#  8   Sex               301721 non-null  object
#  9   AgeCategory       301721 non-null  object
#  10  Race              301721 non-null  object
#  11  Diabetic          301721 non-null  object
#  12  PhysicalActivity  301721 non-null  object
#  13  GenHealth         301721 non-null  object
#  14  SleepTime         301721 non-null  float64
#  15  Asthma            301721 non-null  object
# ...

# %%
disease['HeartDisease'].value_counts()
# Out:
# HeartDisease
# No     274461
# Yes     27260
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
label_enc=LabelEncoder()

# %%
disease['Smoking']=label_enc.fit_transform(disease['Smoking'])

# %%
disease['Smoking']
# Out:
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0
#          ..
# 319790    1
# 319791    1
# 319792    0
# 319793    0
# 319794    0
# Name: Smoking, Length: 301721, dtype: int64

# %%
disease['AlcoholDrinking']=label_enc.fit_transform(disease['AlcoholDrinking'])

# %%
disease['AlcoholDrinking']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 319790    0
# 319791    0
# 319792    0
# 319793    0
# 319794    0
# Name: AlcoholDrinking, Length: 301721, dtype: int32

# %%
disease['Stroke_enc']=label_enc.fit_transform(disease['Stroke'])
disease[['Stroke_enc','Stroke']]
# Out:
#         Stroke_enc Stroke
# 0                0     No
# 1                1    Yes
# 2                0     No
# 3                0     No
# 4                0     No
# ...            ...    ...
# 319790           0     No
# 319791           0     No
# 319792           0     No
# 319793           0     No
# 319794           0     No
#
# [301721 rows x 2 columns]

# %%
disease['Sex_enc']=label_enc.fit_transform(disease['Sex'])
disease[['Sex_enc','Sex']]
# Out:
#         Sex_enc     Sex
# 0             0  Female
# 1             0  Female
# 2             1    Male
# 3             0  Female
# 4             0  Female
# ...         ...     ...
# 319790        1    Male
# 319791        1    Male
# 319792        0  Female
# 319793        0  Female
# 319794        0  Female
#
# [301721 rows x 2 columns]

# %%
disease['DiffWalking_enc']=label_enc.fit_transform(disease['DiffWalking'])
disease[['DiffWalking_enc','DiffWalking']]
# Out:
#         DiffWalking_enc DiffWalking
# 0                     0          No
# 1                     0          No
# 2                     0          No
# 3                     0          No
# 4                     1         Yes
# ...                 ...         ...
# 319790                1         Yes
# 319791                0          No
# 319792                0          No
# 319793                0          No
# 319794                0          No
#
# [301721 rows x 2 columns]

# %%
disease['AgeCategory_enc']=label_enc.fit_transform(disease['AgeCategory'])
disease[['AgeCategory_enc','AgeCategory']]
# Out:
#         AgeCategory_enc  AgeCategory
# 0                     7        55-59
# 1                    12  80 or older
# 2                     9        65-69
# 3                    11        75-79
# 4                     4        40-44
# ...                 ...          ...
# 319790                8        60-64
# 319791                3        35-39
# 319792                5        45-49
# 319793                1        25-29
# 319794               12  80 or older
#
# [301721 rows x 2 columns]

# %%
disease['Race_enc']=label_enc.fit_transform(disease['Race'])
disease[['Race_enc','Race']]
# Out:
#         Race_enc      Race
# 0              5     White
# 1              5     White
# 2              5     White
# 3              5     White
# 4              5     White
# ...          ...       ...
# 319790         3  Hispanic
# 319791         3  Hispanic
# 319792         3  Hispanic
# 319793         3  Hispanic
# 319794         3  Hispanic
#
# [301721 rows x 2 columns]

# %%
disease['Diabetic_enc']=label_enc.fit_transform(disease['Diabetic'])
disease[['Diabetic_enc','Diabetic']]
# Out:
#         Diabetic_enc Diabetic
# 0                  2      Yes
# 1                  0       No
# 2                  2      Yes
# 3                  0       No
# 4                  0       No
# ...              ...      ...
# 319790             2      Yes
# 319791             0       No
# 319792             0       No
# 319793             0       No
# 319794             0       No
#
# [301721 rows x 2 columns]

# %%
disease['PhysicalActivity_enc']=label_enc.fit_transform(disease['PhysicalActivity'])
disease[['PhysicalActivity_enc','PhysicalActivity']]
# Out:
#         PhysicalActivity_enc PhysicalActivity
# 0                          1              Yes
# 1                          1              Yes
# 2                          1              Yes
# 3                          0               No
# 4                          1              Yes
# ...                      ...              ...
# 319790                     0               No
# 319791                     1              Yes
# 319792                     1              Yes
# 319793                     0               No
# 319794                     1              Yes
#
# [301721 rows x 2 columns]

# %%
disease['GenHealth_enc']=label_enc.fit_transform(disease['GenHealth'])
disease[['GenHealth_enc','GenHealth']]
# Out:
#         GenHealth_enc  GenHealth
# 0                   4  Very good
# 1                   4  Very good
# 2                   1       Fair
# 3                   2       Good
# 4                   4  Very good
# ...               ...        ...
# 319790              1       Fair
# 319791              4  Very good
# 319792              2       Good
# 319793              2       Good
# 319794              2       Good
#
# [301721 rows x 2 columns]

# %%
disease['GenHealth_enc']=label_enc.fit_transform(disease['GenHealth'])
disease[['GenHealth_enc','GenHealth']]
# Out:
#         GenHealth_enc  GenHealth
# 0                   4  Very good
# 1                   4  Very good
# 2                   1       Fair
# 3                   2       Good
# 4                   4  Very good
# ...               ...        ...
# 319790              1       Fair
# 319791              4  Very good
# 319792              2       Good
# 319793              2       Good
# 319794              2       Good
#
# [301721 rows x 2 columns]

# %%
disease['Asthma_enc']=label_enc.fit_transform(disease['Asthma'])
disease[['Asthma_enc','Asthma']]
# Out:
#         Asthma_enc Asthma
# 0                1    Yes
# 1                0     No
# 2                1    Yes
# 3                0     No
# 4                0     No
# ...            ...    ...
# 319790           1    Yes
# 319791           1    Yes
# 319792           0     No
# 319793           0     No
# 319794           0     No
#
# [301721 rows x 2 columns]

# %%
disease['KidneyDisease_enc']=label_enc.fit_transform(disease['KidneyDisease'])
disease[['KidneyDisease_enc','KidneyDisease']]
# Out:
#         KidneyDisease_enc KidneyDisease
# 0                       0            No
# 1                       0            No
# 2                       0            No
# 3                       0            No
# 4                       0            No
# ...                   ...           ...
# 319790                  0            No
# 319791                  0            No
# 319792                  0            No
# 319793                  0            No
# 319794                  0            No
#
# [301721 rows x 2 columns]

# %%
disease['SkinCancer_enc']=label_enc.fit_transform(disease['SkinCancer'])
disease[['SkinCancer_enc','SkinCancer']]
# Out:
#         SkinCancer_enc SkinCancer
# 0                    1        Yes
# 1                    0         No
# 2                    0         No
# 3                    1        Yes
# 4                    0         No
# ...                ...        ...
# 319790               0         No
# 319791               0         No
# 319792               0         No
# 319793               0         No
# 319794               0         No
#
# [301721 rows x 2 columns]

# %%
disease.to_csv("heart_disease.csv")

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('Heart_Disease.csv')

# %%
display(data.head())
# Out:
#    Unnamed: 0 HeartDisease    BMI  Smoking  AlcoholDrinking Stroke  \
# 0           0           No  16.60        1                0     No
# 1           1           No  20.34        0                0    Yes
# 2           2           No  26.58        1                0     No
# 3           3           No  24.21        0                0     No
# 4           4           No  23.71        0                0     No
#
#    PhysicalHealth  MentalHealth DiffWalking     Sex  ... Sex_enc  \
# 0             3.0          30.0          No  Female  ...       0
# 1             0.0           0.0          No  Female  ...       0
# 2            20.0          30.0          No    Male  ...       1
# 3             0.0           0.0          No  Female  ...       0
# 4            28.0           0.0         Yes  Female  ...       0
#
#   DiffWalking_enc AgeCategory_enc Race_enc Diabetic_enc  PhysicalActivity_enc  \
# 0               0               7        5            2                     1
# ...

# %%
plt.scatter(data['HeartDisease'],data['GenHealth'])
plt.title("Scatter Plot for Heart Disease vs GenHealth")
plt.xlabel('GenHealth')
plt.ylabel('Heart Disease')
plt.show()

# %%
plt.scatter(data['PhysicalHealth'],data['PhysicalActivity'])
plt.title("Scatter Plot for Physical Health vs PhysicalActivity")
plt.xlabel('PhysicalActivity')
plt.ylabel('Physical Health')
plt.show()
